# %%
import requests
import aiohttp
import asyncio
import pymongo
import time
import io

# %%
conn_string = "mongodb://348637349:g75eu2vh@localhost:27017/?authMechanism=DEFAULT"
client = pymongo.MongoClient(conn_string)
db = client['cc_capstone']
col = db['warc_index']

url = "https://data.commoncrawl.org/crawl-data/CC-MAIN-2023-40/segments/1695233506339.10/warc/CC-MAIN-20230922070214-20230922100214-00874.warc.gz"

matches = col.find({ "id": "crawl-data/CC-MAIN-2023-40/segments/1695233506339.10/warc/CC-MAIN-20230922070214-20230922100214-00874.warc.gz" }).sort("offset", 1)

# %%
ranges = [f"{i['offset']}-{i['offset'] + i['length'] - 1}" for i in matches]
# ranges = ranges[:2]

# %%
# single request, synchronous
sess = requests.Session()
s_time = time.monotonic()

extrapolate = 7 * 10
n_reqs = extrapolate * 1_000_000 / len(ranges)

with sess.get(url, headers={"Range": f"bytes={', '.join(ranges)}"}) as resp:
    # print(resp.status_code)
    with open(f"../testfolder/{url.split('/warc/', 1)[1]}", "wb") as f:
        f.write(resp.content)
    # print(resp.content)

e_time = time.monotonic()

print(f"Time: {e_time - s_time} for {len(ranges)} ranges")
print(f"Estimated time for {extrapolate} million WARCs (1 PID): {n_reqs * (e_time - s_time) / 60 / 60 / 24} days")
print(f"Estimated time for {extrapolate} million WARCs (5 PID): {n_reqs * (e_time - s_time) / 60 / 60 / 24 / 5} days")
print(f"Estimated time for {extrapolate} million WARCs (10 PID): {n_reqs * (e_time - s_time) / 60 / 60 / 24 / 10} days")
# Out:
# Time: 11.812999999994645 for 78 ranges
# Estimated time for 70 million WARCs (1 PID): 122.7015075972853 days
# Estimated time for 70 million WARCs (5 PID): 24.54030151945706 days
# Estimated time for 70 million WARCs (10 PID): 12.27015075972853 days

# %%
TODO

HEY! FIX PROBLEM WITH CC-MAIN-20230929190403-20230929220403-00373!!!

# %%
flag = 5
with open("../filtered/TEMP-CC-MAIN-20230929190403-20230929220403-00373.warc.gz", "rb") as f, open("../filtered/CLEAN-CC-MAIN-20230929190403-20230929220403-00373.warc.gz", "wb") as outfile:
# with open(f"../testfolder/{url.split('/warc/', 1)[1]}", "rb") as f, open(f"../testfolder/CLEAN-{url.split('/warc/', 1)[1]}", "wb") as outfile:
    for line in f:
        if flag > 0:
            flag -= 1
            continue

        if line.startswith(b"--CloudFront:"):
            flag = 3

            # seek to the line before this one
            outfile.seek(outfile.tell() - len(b"\r\n"))

            continue
            
        outfile.write(line)

    outfile.seek(outfile.tell() - len(b"\r\n"))
    outfile.truncate()

# %%
sess.close()

# %%
sess = aiohttp.ClientSession()

async def fetch(url, range):
    async with sess.get(url, headers={"Range": f"bytes={range}"}) as resp:
        if resp.status != 206:
            print("Problem")
        
        open(f"../testfolder/test-{range}.warc.gz", "wb").write(await resp.read())

async def main():
    tasks = []
    for range in ranges:
        tasks.append(asyncio.create_task(fetch(url, range)))

    await asyncio.gather(*tasks)

start = time.monotonic()

loop = asyncio.get_event_loop()
loop.create_task(main())

end = time.monotonic()

print(f"Time: {end - start} for {len(ranges)} ranges")

sess.close()
# Out:
# Time: 0.0 for 2 ranges
# <coroutine object ClientSession.close at 0x0000023A717BBE80>

# %%
import os
from warcio.archiveiterator import ArchiveIterator as WARCIOIterator

# %%
files = os.listdir("../testfolder")

with open(f"../testfolder/CLEANCOMPARE-{url.split('/warc/', 1)[1]}", "wb") as outfile:
    for file in files:
        with open(f"../testfolder/{file}", "rb") as f:
            outfile.write(f.read())

# %%
from fastwarc.warc import ArchiveIterator as FASTWARCIterator

# %%
# file = f"../testfolder/CLEAN-{url.split('/warc/', 1)[1]}"
file = f"../filtered/CC-MAIN-20230922034112-20230922064112-00733.warc.gz"
loops = 100
count = 0
extrapolate = 7 * 300 * 2

s_time = time.monotonic()

for _ in range(loops):
    for warc in FASTWARCIterator(open(file, 'rb')):
        target = warc.record_id
        count += 1

e_time = time.monotonic()

n_reqs = extrapolate * 1_000_000 / (loops * count)

print(f"Time: {e_time - s_time}s for {loops} file (FASTWARC)")
print(f"Estimated time for {extrapolate} million WARCs: {n_reqs * (e_time - s_time) / 60 / 60} hours")
print("")

count = 0

s_time = time.monotonic()
for _ in range(loops):
    for warc in WARCIOIterator(open(file, 'rb')):
        target = warc.rec_headers.get_header('WARC-Record-ID')
        count += 1
    
e_time = time.monotonic()

n_reqs = extrapolate * 1_000_000 / (loops * count)

print(f"Time: {e_time - s_time}s for {loops} file (WARCIO)")
print(f"Estimated time for {extrapolate} million WARCs: {n_reqs * (e_time - s_time) / 60 / 60} hours")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
#         <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#        	<link rel="icon"  type="image/png"  href="http://142.54.174.28/assets/web/images/favicon_new.png">
#         <title>Agen Bandar Togel Online, Togel Singapura, Togel Hongkong</title>
#         <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
#          <meta name="allow-search" content="Yes">
#          <meta name="ROBOTS" content="All">
#          <meta name="robots" content="index, follow"/>
#          <meta name="keywords" content="Daftar Togel, Agen Togel, Agen Togel Online, Bandar Togel, Bandar Togel Online, Judi Togel, Judi Online, Judi Togel Online, Togel Online, Togel Singapura, Togel Hongkong, Slot Online, Live Casino, Casino Online" />
# ...

# %%
files = os.listdir("./testfolder")

with open("./testfolder/combined.warc.gz", "wb") as f:
    for file in files:
        f.write(open(f"./testfolder/{file}", "rb").read())

# %%
count = 0

s_time = time.monotonic_ns()

for warc in WARCIOIterator(open(f"../testfolder/CLEAN-{url.split('/warc/', 1)[1]}", 'rb')):
    target = warc.rec_headers.get_header('WARC-Record-ID')
    count += 1

e_time = time.monotonic_ns()

print(f"WARCIO took {e_time - s_time} seconds for {count} records (@ {count / (e_time - s_time)} records/second)")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[71], line 11
#       7     count += 1
#       9 e_time = time.monotonic_ns()
# ---> 11 print(f"WARCIO took {e_time - s_time} seconds for {count} records (@ {count / (e_time - s_time)} records/second)")
#
# ZeroDivisionError: division by zero

# %%
count = 0

s_time = time.monotonic()

file = f"../filtered/CC-MAIN-20230925051501-20230925081501-00186.warc.gz"

for warc in FASTWARCIterator(open(file, "rb")):
# for warc in FASTWARCIterator(open(f"../testfolder/CLEANCOMPARE-{url.split('/warc/', 1)[1]}", 'rb')):
    target = warc.record_id
    # print(target)
    count += 1

e_time = time.monotonic()

print(f"FASTWARC took {e_time - s_time} seconds for {count} records (@ {count / (e_time - s_time)} records/second)")
# Out:
# <urn:uuid:5d6b5ad8-08ee-47a6-990d-bd19593ce525>
# <urn:uuid:cd786a9f-34f8-497f-9c85-2f6b539e7ca4>
# <urn:uuid:b0a5839e-912d-44d0-b508-656b7a371308>
# <urn:uuid:ffdb0632-3767-42fc-b2b6-21d9730f49d8>
# <urn:uuid:8b2ce961-1b4d-4221-bff3-f54883b5212e>
# <urn:uuid:95851b39-28d7-4e7c-ae16-af04b8230928>
# <urn:uuid:e26ae358-d77f-477e-8edc-19436c4ecb59>
# <urn:uuid:7618e9d2-47b6-42bf-8b2f-7c936782ffd1>
# <urn:uuid:2b6049d8-ac61-4e74-94f8-109598c244c3>
# <urn:uuid:e23d5a07-d5a7-47f4-9369-943d4b3b0b30>
# <urn:uuid:d54d617f-99de-4c1a-852c-b55440d6fdf7>
# <urn:uuid:bdeed2a3-9aee-4466-bd87-461837524712>
# <urn:uuid:fd0e5e08-6afd-4e2f-b815-7eb04357d74c>
# <urn:uuid:6d227587-898f-47ce-b0e5-68edd4f8b10e>
# <urn:uuid:b15cc4f7-c033-41e9-a6bc-c7a63f2999cf>
# <urn:uuid:00abc66d-b5a7-445e-9894-dc68772136c0>
# <urn:uuid:212cdd8a-44ac-431e-bd35-62acde16fe13>
# <urn:uuid:4338c5da-d771-4e44-93e6-a26430f87bd4>
# <urn:uuid:5f9d2170-4478-423a-8b8a-a43ae26c50cb>
# <urn:uuid:14871a75-25c4-4750-ad02-a7da61c8470f>
# ...
